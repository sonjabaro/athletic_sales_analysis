# %%
# Import Libraries and Dependencies
import pandas as pd

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
Data_2020_df = pd.read_csv("../athletic_sales_analysis/Resources/athletic_sales_2020.csv")
Data_2021_df = pd.read_csv("../athletic_sales_analysis/Resources/athletic_sales_2021.csv")

# %%
# Display the 2020 sales DataFrame
Data_2020_df.head()
# Out:
#       retailer  retailer_id invoice_date     region         state  \
# 0  Foot Locker      1185732       1/1/20  Northeast      New York
# 1  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3  Foot Locker      1185732       1/1/20  Northeast      New York
# 4  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
#
#            city                product  price_per_unit  units_sold  \
# 0      New York  Men's Street Footwear              50        1200
# 1  Philadelphia        Women's Apparel              68          83
# 2  Philadelphia        Women's Apparel              75         275
# 3      New York  Men's Street Footwear              34         384
# 4  Philadelphia        Women's Apparel              53          83
#
#    total_sales  operating_profit sales_method
# 0       600000         300000.00     In-store
# 1         5644           2426.92       Online
# ...

# %%
# I want to understand the volume of data/rows I have
Data_2020_df.shape
# Out:
# (1297, 12)

# %%
Data_2021_df.shape
# Out:
# (8346, 12)

# %%
# Display the 2021 sales DataFrame
Data_2021_df.head()
# Out:
#     retailer  retailer_id invoice_date   region       state           city  \
# 0  West Gear      1128299       1/1/21     West  California  San Francisco
# 1  West Gear      1128299       1/1/21     West  California  San Francisco
# 2     Kohl's      1189833       1/1/21  Midwest     Montana       Billings
# 3     Kohl's      1189833       1/1/21  Midwest     Montana       Billings
# 4  West Gear      1128299       1/1/21     West  California  San Francisco
#
#                    product  price_per_unit  units_sold  total_sales  \
# 0  Men's Athletic Footwear              65         750       487500
# 1  Men's Athletic Footwear              51         233        11883
# 2            Men's Apparel              50         275       137500
# 3            Men's Apparel              47          77         3619
# 4  Men's Athletic Footwear              64         225        14400
#
#    operating_profit sales_method
# 0         121875.00       Outlet
# 1           3208.41       Outlet
# ...

# %%
Data_2021_df.tail()
#I notice that the retailer_id isn't necessarily unique - why?see 1185732 repeated for different retailers and in different locations as well as sales method
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#               city        product  price_per_unit  units_sold  total_sales  \
# 8341  Philadelphia  Men's Apparel              63          47         2961
# 8342  Philadelphia  Men's Apparel              46          56         2576
# 8343      Portland  Men's Apparel              52          36         1872
# 8344      Portland  Men's Apparel              55         125        68750
# 8345  Philadelphia  Men's Apparel              70         175       122500
#
#       operating_profit sales_method
# 8341           1362.06       Online
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
Data_2020_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Check the 2021 sales data types.
Data_2021_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
#What is the count of each value for the files?


for column in Data_2020_df.columns:
    value_counts = Data_2020_df[column].value_counts()
    print(f"Value counts for column '{column}':\n{value_counts}\n")
#notice there are 5 retailers,yet 4 retailer ids, retailer ids aren't unique to the actual store or even the store itself - what does that id stand for??(see block of code 2 boxes below)
# Out:
# Value counts for column 'retailer':
# retailer
# West Gear        632
# Foot Locker      337
# Walmart          216
# Sports Direct    106
# Kohl's             6
# Name: count, dtype: int64
#
# Value counts for column 'retailer_id':
# retailer_id
# 1128299    580
# 1185732    495
# 1197831    216
# 1189833      6
# Name: count, dtype: int64
#
# Value counts for column 'invoice_date':
# invoice_date
# 4/24/20    33
# 5/24/20    14
# 1/1/20      6
# 2/2/20      6
# 2/3/20      6
#            ..
# 7/17/20     2
# 5/8/20      2
# 4/16/20     2
# 4/15/20     2
# 6/29/20     2
# Name: count, Length: 358, dtype: int64
#
# Value counts for column 'region':
# region
# West         564
# Northeast    231
# South        216
# Southeast    144
# Midwest      142
# Name: count, dtype: int64
#
# Value counts for column 'state':
# state
# New York        216
# Nevada          216
# Texas           216
# Colorado        144
# Florida         144
# Washington      144
# Minnesota       142
# ...

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
#Because my data has the same columns I can stack the data using concat. 
joined_data_rows = pd.concat([Data_2020_df,Data_2021_df], axis="rows", join="inner")
joined_data_rows.tail(25)
#the index just adds the
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 8321       Amazon      1185732     12/27/21  Northeast         Maine
# 8322  Foot Locker      1185732     12/27/21  Northeast  Pennsylvania
# 8323       Amazon      1185732     12/27/21  Northeast         Maine
# 8324  Foot Locker      1185732     12/27/21  Northeast  Pennsylvania
# 8325  Foot Locker      1185732     12/27/21  Northeast  Pennsylvania
# 8326  Foot Locker      1185732     12/28/21  Northeast  Pennsylvania
# 8327  Foot Locker      1185732     12/28/21  Northeast  Pennsylvania
# 8328  Foot Locker      1185732     12/28/21  Northeast  Pennsylvania
# 8329       Amazon      1185732     12/28/21  Northeast         Maine
# 8330       Amazon      1185732     12/28/21  Northeast         Maine
# 8331  Foot Locker      1185732     12/29/21  Northeast  Pennsylvania
# 8332       Amazon      1185732     12/29/21  Northeast         Maine
# 8333  Foot Locker      1185732     12/29/21  Northeast  Pennsylvania
# ...

# %%
#Find unique values
for column in Data_2021_df.columns:
    unique_values = Data_2021_df["retailer_id"].unique()

unique_values
# Out:
# array([1128299, 1189833, 1185732, 1197831])

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.

# %%
Data_2020_df.set_index(["retailer_id","retailer"],inplace=True)
Data_2021_df.set_index(["retailer_id","retailer"], inplace= True)

# %%
sales_data_2020_21 = Data_2021_df.join(Data_2020_df, lsuffix="_2021", rsuffix="_2020")
sales_data_2020_21
# Out:
#                         invoice_date_2021 region_2021 state_2021    city_2021  \
# retailer_id retailer
# 1128299     Foot Locker           1/10/21        West     Alaska    Anchorage
#             Foot Locker           1/10/21        West     Alaska    Anchorage
#             Foot Locker           1/10/21        West     Alaska    Anchorage
#             Foot Locker           1/10/21        West     Alaska    Anchorage
#             Foot Locker           1/10/21        West     Alaska    Anchorage
# ...                                   ...         ...        ...          ...
# 1197831     West Gear            12/19/21       South   Arkansas  Little Rock
#             West Gear            12/19/21       South   Arkansas  Little Rock
#             West Gear            12/19/21       South   Arkansas  Little Rock
#             West Gear            12/19/21       South   Arkansas  Little Rock
#             West Gear            12/19/21       South   Arkansas  Little Rock
#
# ...

# %%
# Check if any values are null.

# %%
# Check the data type of each column

# %%
# Convert the "invoice_date" to a datetime datatype

# %%
# Confirm that the "invoice_date" data type has been changed.

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".




# Show the top 5 results.

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.


# Rename the "units_sold" column to "Total_Products_Sold"


# Show the top 5 results.

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
# Rename the "total_sales" column to "Total Sales"


# Show the top 5 results.

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.


# Optional: Rename the "total_sales" column to "Total Sales"


# Show the top 5 results.

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
# Rename the "total_sales" column to "Total Sales"

# Show the top 5 results.

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.


# Optional: Rename the "total_sales" column to "Total Sales"


# Show the top 5 results.

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"

# Show the top 5 results.

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.


# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"

# Show the top 5 results.

# %% [markdown]
# ### 5. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.


# Optional: Rename the "total_sales" column to "Total Sales"


# Show the table.

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.


# Sort the resampled pivot table in ascending order on "Total Sales".

# %% [markdown]
# ### 6.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.


# Sort the resampled pivot table in ascending order on "Total Sales".
